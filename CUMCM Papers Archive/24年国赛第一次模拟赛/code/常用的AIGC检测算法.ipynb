# %%
import numpy as np

X_reduced = np.load('特征储存.npy')
y = np.load('标签储存.npy')

print(X_reduced.shape)
print(y.shape)
# Out:
# (200, 100)
# (200,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.2, random_state=42)

from sklearn.metrics import classification_report, accuracy_score

# Logistic Regression
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)

print('Logistic Regression')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        19
#            1       0.91      1.00      0.95        21
#
#     accuracy                           0.95        40
#    macro avg       0.96      0.95      0.95        40
# weighted avg       0.95      0.95      0.95        40

# %%
# SVM
from sklearn.svm import SVC

svm = SVC()
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)

print('SVM')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# SVM
# Accuracy: 0.925
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91        19
#            1       0.88      1.00      0.93        21
#
#     accuracy                           0.93        40
#    macro avg       0.94      0.92      0.92        40
# weighted avg       0.93      0.93      0.92        40

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

print('Random Forest')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Random Forest
# Accuracy: 0.875
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        19
#            1       0.90      0.86      0.88        21
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.88      0.87        40
# weighted avg       0.88      0.88      0.88        40

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)

print('Naive Bayes')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Naive Bayes
# Accuracy: 0.675
#               precision    recall  f1-score   support
#
#            0       0.64      0.74      0.68        19
#            1       0.72      0.62      0.67        21
#
#     accuracy                           0.68        40
#    macro avg       0.68      0.68      0.67        40
# weighted avg       0.68      0.68      0.67        40

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print('KNN')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# KNN
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81        19
#            1       0.78      1.00      0.88        21
#
#     accuracy                           0.85        40
#    macro avg       0.89      0.84      0.84        40
# weighted avg       0.88      0.85      0.85        40

# %%
# LightGBM
import lightgbm as lgb

lgb_train = lgb.Dataset(X_train, y_train)
lgb_test = lgb.Dataset(X_test, y_test)

params = {
    'objective': 'binary',
    'metric': 'binary_error',
    'verbosity': -1
}

lgb_model = lgb.train(params, lgb_train, valid_sets=lgb_test, num_boost_round=1000)

y_pred = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)
y_pred = np.round(y_pred)

print('LightGBM')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# LightGBM
# Accuracy: 0.9
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        19
#            1       0.84      1.00      0.91        21
#
#     accuracy                           0.90        40
#    macro avg       0.92      0.89      0.90        40
# weighted avg       0.92      0.90      0.90        40

# %%
# XGBoost
import xgboost as xgb

xgb_train = xgb.DMatrix(X_train, label=y_train)
xgb_test = xgb.DMatrix(X_test, label=y_test)

params = {
    'objective': 'binary:logistic',
    'eval_metric': 'error'
}

xgb_model = xgb.train(params, xgb_train, num_boost_round=1000, evals=[(xgb_test, 'test')])
y_pred = xgb_model.predict(xgb_test)
y_pred = np.round(y_pred)

print('XGBoost')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [0]	test-error:0.17500
# [1]	test-error:0.20000
# [2]	test-error:0.20000
# [3]	test-error:0.12500
# [4]	test-error:0.12500
# [5]	test-error:0.10000
# [6]	test-error:0.10000
# [7]	test-error:0.07500
# [8]	test-error:0.10000
# [9]	test-error:0.07500
# [10]	test-error:0.07500
# [11]	test-error:0.10000
# [12]	test-error:0.12500
# [13]	test-error:0.07500
# [14]	test-error:0.10000
# [15]	test-error:0.10000
# [16]	test-error:0.12500
# [17]	test-error:0.12500
# [18]	test-error:0.12500
# [19]	test-error:0.12500
# [20]	test-error:0.10000
# [21]	test-error:0.12500
# [22]	test-error:0.10000
# [23]	test-error:0.12500
# [24]	test-error:0.12500
# [25]	test-error:0.10000
# [26]	test-error:0.12500
# [27]	test-error:0.12500
# [28]	test-error:0.12500
# [29]	test-error:0.12500
# [30]	test-error:0.12500
# [31]	test-error:0.12500
# [32]	test-error:0.10000
# [33]	test-error:0.12500
# [34]	test-error:0.10000
# [35]	test-error:0.10000
# [36]	test-error:0.10000
# [37]	test-error:0.12500
# [38]	test-error:0.10000
# [39]	test-error:0.10000
# [40]	test-error:0.10000
# [41]	test-error:0.10000
# [42]	test-error:0.10000
# [43]	test-error:0.10000
# [44]	test-error:0.10000
# [45]	test-error:0.07500
# [46]	test-error:0.07500
# [47]	test-error:0.07500
# [48]	test-error:0.10000
# [49]	test-error:0.07500
# [50]	test-error:0.07500
# [51]	test-error:0.07500
# [52]	test-error:0.07500
# [53]	test-error:0.07500
# [54]	test-error:0.07500
# [55]	test-error:0.07500
# [56]	test-error:0.07500
# [57]	test-error:0.07500
# [58]	test-error:0.07500
# [59]	test-error:0.07500
# [60]	test-error:0.07500
# [61]	test-error:0.07500
# [62]	test-error:0.07500
# [63]	test-error:0.07500
# [64]	test-error:0.10000
# [65]	test-error:0.07500
# [66]	test-error:0.07500
# [67]	test-error:0.07500
# [68]	test-error:0.07500
# [69]	test-error:0.07500
# [70]	test-error:0.07500
# [71]	test-error:0.07500
# [72]	test-error:0.07500
# [73]	test-error:0.07500
# [74]	test-error:0.10000
# [75]	test-error:0.07500
# [76]	test-error:0.07500
# [77]	test-error:0.07500
# [78]	test-error:0.07500
# [79]	test-error:0.07500
# [80]	test-error:0.07500
# [81]	test-error:0.07500
# [82]	test-error:0.07500
# [83]	test-error:0.07500
# [84]	test-error:0.07500
# [85]	test-error:0.07500
# [86]	test-error:0.07500
# [87]	test-error:0.07500
# [88]	test-error:0.07500
# [89]	test-error:0.07500
# [90]	test-error:0.07500
# [91]	test-error:0.07500
# [92]	test-error:0.07500
# [93]	test-error:0.07500
# [94]	test-error:0.07500
# [95]	test-error:0.07500
# [96]	test-error:0.07500
# [97]	test-error:0.07500
# [98]	test-error:0.07500
# [99]	test-error:0.07500
# [100]	test-error:0.07500
# [101]	test-error:0.07500
# [102]	test-error:0.07500
# [103]	test-error:0.07500
# [104]	test-error:0.07500
# [105]	test-error:0.07500
# [106]	test-error:0.07500
# [107]	test-error:0.07500
# [108]	test-error:0.07500
# [109]	test-error:0.07500
# [110]	test-error:0.07500
# [111]	test-error:0.07500
# [112]	test-error:0.07500
# [113]	test-error:0.07500
# [114]	test-error:0.07500
# [115]	test-error:0.07500
# [116]	test-error:0.07500
# [117]	test-error:0.07500
# [118]	test-error:0.07500
# [119]	test-error:0.07500
# [120]	test-error:0.07500
# [121]	test-error:0.07500
# [122]	test-error:0.07500
# [123]	test-error:0.07500
# [124]	test-error:0.07500
# [125]	test-error:0.07500
# [126]	test-error:0.07500
# [127]	test-error:0.07500
# [128]	test-error:0.07500
# [129]	test-error:0.07500
# [130]	test-error:0.07500
# [131]	test-error:0.07500
# [132]	test-error:0.07500
# [133]	test-error:0.07500
# [134]	test-error:0.07500
# [135]	test-error:0.07500
# [136]	test-error:0.07500
# [137]	test-error:0.07500
# [138]	test-error:0.07500
# [139]	test-error:0.07500
# [140]	test-error:0.07500
# [141]	test-error:0.07500
# [142]	test-error:0.07500
# [143]	test-error:0.07500
# [144]	test-error:0.07500
# [145]	test-error:0.07500
# [146]	test-error:0.07500
# [147]	test-error:0.07500
# [148]	test-error:0.07500
# [149]	test-error:0.07500
# [150]	test-error:0.07500
# [151]	test-error:0.07500
# [152]	test-error:0.07500
# [153]	test-error:0.07500
# [154]	test-error:0.07500
# [155]	test-error:0.07500
# [156]	test-error:0.07500
# [157]	test-error:0.07500
# [158]	test-error:0.07500
# [159]	test-error:0.07500
# [160]	test-error:0.07500
# [161]	test-error:0.07500
# [162]	test-error:0.07500
# [163]	test-error:0.07500
# [164]	test-error:0.07500
# [165]	test-error:0.07500
# [166]	test-error:0.07500
# [167]	test-error:0.07500
# [168]	test-error:0.07500
# [169]	test-error:0.07500
# [170]	test-error:0.07500
# [171]	test-error:0.07500
# [172]	test-error:0.07500
# [173]	test-error:0.07500
# [174]	test-error:0.07500
# [175]	test-error:0.07500
# [176]	test-error:0.07500
# [177]	test-error:0.07500
# [178]	test-error:0.07500
# [179]	test-error:0.07500
# [180]	test-error:0.07500
# [181]	test-error:0.07500
# [182]	test-error:0.07500
# [183]	test-error:0.07500
# [184]	test-error:0.07500
# [185]	test-error:0.07500
# [186]	test-error:0.07500
# [187]	test-error:0.07500
# [188]	test-error:0.07500
# [189]	test-error:0.07500
# [190]	test-error:0.07500
# [191]	test-error:0.07500
# [192]	test-error:0.07500
# [193]	test-error:0.07500
# [194]	test-error:0.07500
# [195]	test-error:0.07500
# [196]	test-error:0.07500
# [197]	test-error:0.07500
# [198]	test-error:0.07500
# [199]	test-error:0.07500
# [200]	test-error:0.07500
# [201]	test-error:0.07500
# [202]	test-error:0.07500
# [203]	test-error:0.07500
# [204]	test-error:0.07500
# [205]	test-error:0.07500
# [206]	test-error:0.07500
# [207]	test-error:0.07500
# [208]	test-error:0.07500
# [209]	test-error:0.07500
# [210]	test-error:0.07500
# [211]	test-error:0.07500
# [212]	test-error:0.07500
# [213]	test-error:0.07500
# [214]	test-error:0.07500
# [215]	test-error:0.07500
# [216]	test-error:0.07500
# [217]	test-error:0.07500
# [218]	test-error:0.07500
# [219]	test-error:0.07500
# [220]	test-error:0.07500
# [221]	test-error:0.07500
# [222]	test-error:0.07500
# [223]	test-error:0.07500
# [224]	test-error:0.07500
# [225]	test-error:0.07500
# [226]	test-error:0.07500
# [227]	test-error:0.07500
# [228]	test-error:0.07500
# [229]	test-error:0.07500
# [230]	test-error:0.07500
# [231]	test-error:0.07500
# [232]	test-error:0.07500
# [233]	test-error:0.07500
# [234]	test-error:0.07500
# [235]	test-error:0.07500
# [236]	test-error:0.07500
# [237]	test-error:0.07500
# [238]	test-error:0.07500
# [239]	test-error:0.07500
# [240]	test-error:0.07500
# [241]	test-error:0.07500
# [242]	test-error:0.07500
# [243]	test-error:0.07500
# [244]	test-error:0.07500
# [245]	test-error:0.07500
# [246]	test-error:0.07500
# [247]	test-error:0.07500
# [248]	test-error:0.07500
# [249]	test-error:0.07500
# [250]	test-error:0.07500
# [251]	test-error:0.07500
# [252]	test-error:0.07500
# [253]	test-error:0.07500
# [254]	test-error:0.07500
# [255]	test-error:0.07500
# [256]	test-error:0.07500
# [257]	test-error:0.07500
# [258]	test-error:0.07500
# [259]	test-error:0.07500
# [260]	test-error:0.07500
# [261]	test-error:0.07500
# [262]	test-error:0.07500
# [263]	test-error:0.07500
# [264]	test-error:0.07500
# [265]	test-error:0.07500
# [266]	test-error:0.07500
# [267]	test-error:0.07500
# [268]	test-error:0.07500
# [269]	test-error:0.07500
# [270]	test-error:0.07500
# [271]	test-error:0.07500
# [272]	test-error:0.07500
# [273]	test-error:0.07500
# [274]	test-error:0.07500
# [275]	test-error:0.07500
# [276]	test-error:0.07500
# [277]	test-error:0.07500
# [278]	test-error:0.07500
# [279]	test-error:0.07500
# [280]	test-error:0.07500
# [281]	test-error:0.07500
# [282]	test-error:0.07500
# [283]	test-error:0.07500
# [284]	test-error:0.07500
# [285]	test-error:0.07500
# [286]	test-error:0.07500
# [287]	test-error:0.07500
# [288]	test-error:0.07500
# [289]	test-error:0.07500
# [290]	test-error:0.07500
# [291]	test-error:0.07500
# [292]	test-error:0.07500
# [293]	test-error:0.07500
# [294]	test-error:0.07500
# [295]	test-error:0.07500
# [296]	test-error:0.07500
# [297]	test-error:0.07500
# [298]	test-error:0.07500
# [299]	test-error:0.07500
# [300]	test-error:0.07500
# [301]	test-error:0.07500
# [302]	test-error:0.07500
# [303]	test-error:0.07500
# [304]	test-error:0.07500
# [305]	test-error:0.07500
# [306]	test-error:0.07500
# [307]	test-error:0.07500
# [308]	test-error:0.07500
# [309]	test-error:0.07500
# [310]	test-error:0.07500
# [311]	test-error:0.07500
# [312]	test-error:0.07500
# [313]	test-error:0.07500
# [314]	test-error:0.07500
# [315]	test-error:0.07500
# [316]	test-error:0.07500
# [317]	test-error:0.07500
# [318]	test-error:0.07500
# [319]	test-error:0.07500
# [320]	test-error:0.07500
# [321]	test-error:0.07500
# [322]	test-error:0.07500
# [323]	test-error:0.07500
# [324]	test-error:0.07500
# [325]	test-error:0.07500
# [326]	test-error:0.07500
# [327]	test-error:0.07500
# [328]	test-error:0.07500
# [329]	test-error:0.07500
# [330]	test-error:0.07500
# [331]	test-error:0.07500
# [332]	test-error:0.07500
# [333]	test-error:0.07500
# [334]	test-error:0.07500
# [335]	test-error:0.07500
# [336]	test-error:0.07500
# [337]	test-error:0.07500
# [338]	test-error:0.07500
# [339]	test-error:0.07500
# [340]	test-error:0.07500
# [341]	test-error:0.07500
# [342]	test-error:0.07500
# [343]	test-error:0.07500
# [344]	test-error:0.07500
# [345]	test-error:0.07500
# [346]	test-error:0.07500
# [347]	test-error:0.07500
# [348]	test-error:0.07500
# [349]	test-error:0.07500
# [350]	test-error:0.07500
# [351]	test-error:0.07500
# [352]	test-error:0.07500
# [353]	test-error:0.07500
# [354]	test-error:0.07500
# [355]	test-error:0.07500
# [356]	test-error:0.07500
# [357]	test-error:0.07500
# [358]	test-error:0.07500
# [359]	test-error:0.07500
# [360]	test-error:0.07500
# [361]	test-error:0.07500
# [362]	test-error:0.07500
# [363]	test-error:0.07500
# [364]	test-error:0.07500
# [365]	test-error:0.07500
# [366]	test-error:0.07500
# [367]	test-error:0.07500
# [368]	test-error:0.07500
# [369]	test-error:0.07500
# [370]	test-error:0.07500
# [371]	test-error:0.07500
# [372]	test-error:0.07500
# [373]	test-error:0.07500
# [374]	test-error:0.07500
# [375]	test-error:0.07500
# [376]	test-error:0.07500
# [377]	test-error:0.07500
# [378]	test-error:0.07500
# [379]	test-error:0.07500
# [380]	test-error:0.07500
# [381]	test-error:0.07500
# [382]	test-error:0.07500
# [383]	test-error:0.07500
# [384]	test-error:0.07500
# [385]	test-error:0.07500
# [386]	test-error:0.07500
# [387]	test-error:0.07500
# [388]	test-error:0.07500
# [389]	test-error:0.07500
# [390]	test-error:0.07500
# [391]	test-error:0.07500
# [392]	test-error:0.07500
# [393]	test-error:0.07500
# [394]	test-error:0.07500
# [395]	test-error:0.07500
# [396]	test-error:0.07500
# [397]	test-error:0.07500
# [398]	test-error:0.07500
# [399]	test-error:0.07500
# [400]	test-error:0.07500
# [401]	test-error:0.07500
# [402]	test-error:0.07500
# [403]	test-error:0.07500
# [404]	test-error:0.07500
# [405]	test-error:0.07500
# [406]	test-error:0.07500
# [407]	test-error:0.07500
# [408]	test-error:0.07500
# [409]	test-error:0.07500
# [410]	test-error:0.07500
# [411]	test-error:0.07500
# [412]	test-error:0.07500
# [413]	test-error:0.07500
# [414]	test-error:0.07500
# [415]	test-error:0.07500
# [416]	test-error:0.07500
# [417]	test-error:0.07500
# [418]	test-error:0.07500
# [419]	test-error:0.07500
# [420]	test-error:0.07500
# [421]	test-error:0.07500
# [422]	test-error:0.07500
# [423]	test-error:0.07500
# [424]	test-error:0.07500
# [425]	test-error:0.07500
# [426]	test-error:0.07500
# [427]	test-error:0.07500
# [428]	test-error:0.07500
# [429]	test-error:0.07500
# [430]	test-error:0.07500
# [431]	test-error:0.07500
# [432]	test-error:0.07500
# [433]	test-error:0.07500
# [434]	test-error:0.07500
# [435]	test-error:0.07500
# [436]	test-error:0.07500
# [437]	test-error:0.07500
# [438]	test-error:0.07500
# [439]	test-error:0.07500
# [440]	test-error:0.07500
# [441]	test-error:0.07500
# [442]	test-error:0.07500
# [443]	test-error:0.07500
# [444]	test-error:0.07500
# [445]	test-error:0.07500
# [446]	test-error:0.07500
# [447]	test-error:0.07500
# [448]	test-error:0.07500
# [449]	test-error:0.07500
# [450]	test-error:0.07500
# [451]	test-error:0.07500
# [452]	test-error:0.07500
# [453]	test-error:0.07500
# [454]	test-error:0.07500
# [455]	test-error:0.07500
# [456]	test-error:0.07500
# [457]	test-error:0.07500
# [458]	test-error:0.07500
# [459]	test-error:0.07500
# [460]	test-error:0.07500
# [461]	test-error:0.07500
# [462]	test-error:0.07500
# [463]	test-error:0.07500
# [464]	test-error:0.07500
# [465]	test-error:0.07500
# [466]	test-error:0.07500
# [467]	test-error:0.07500
# [468]	test-error:0.07500
# [469]	test-error:0.07500
# [470]	test-error:0.07500
# [471]	test-error:0.07500
# [472]	test-error:0.07500
# [473]	test-error:0.07500
# [474]	test-error:0.07500
# [475]	test-error:0.07500
# [476]	test-error:0.07500
# [477]	test-error:0.07500
# [478]	test-error:0.07500
# [479]	test-error:0.07500
# [480]	test-error:0.07500
# [481]	test-error:0.07500
# [482]	test-error:0.07500
# [483]	test-error:0.07500
# [484]	test-error:0.07500
# [485]	test-error:0.07500
# [486]	test-error:0.07500
# [487]	test-error:0.07500
# [488]	test-error:0.07500
# [489]	test-error:0.07500
# [490]	test-error:0.07500
# [491]	test-error:0.07500
# [492]	test-error:0.07500
# [493]	test-error:0.07500
# [494]	test-error:0.07500
# [495]	test-error:0.07500
# [496]	test-error:0.07500
# [497]	test-error:0.07500
# [498]	test-error:0.07500
# [499]	test-error:0.07500
# [500]	test-error:0.07500
# [501]	test-error:0.07500
# [502]	test-error:0.07500
# [503]	test-error:0.07500
# [504]	test-error:0.07500
# [505]	test-error:0.07500
# [506]	test-error:0.07500
# [507]	test-error:0.07500
# [508]	test-error:0.07500
# [509]	test-error:0.07500
# [510]	test-error:0.07500
# [511]	test-error:0.07500
# [512]	test-error:0.07500
# [513]	test-error:0.07500
# [514]	test-error:0.07500
# [515]	test-error:0.07500
# [516]	test-error:0.07500
# [517]	test-error:0.07500
# [518]	test-error:0.07500
# [519]	test-error:0.07500
# [520]	test-error:0.07500
# [521]	test-error:0.07500
# [522]	test-error:0.07500
# [523]	test-error:0.07500
# [524]	test-error:0.07500
# [525]	test-error:0.07500
# [526]	test-error:0.07500
# [527]	test-error:0.07500
# [528]	test-error:0.07500
# [529]	test-error:0.07500
# [530]	test-error:0.07500
# [531]	test-error:0.07500
# [532]	test-error:0.07500
# [533]	test-error:0.07500
# [534]	test-error:0.07500
# [535]	test-error:0.07500
# [536]	test-error:0.07500
# [537]	test-error:0.07500
# [538]	test-error:0.07500
# [539]	test-error:0.07500
# [540]	test-error:0.07500
# [541]	test-error:0.07500
# [542]	test-error:0.07500
# [543]	test-error:0.07500
# [544]	test-error:0.07500
# [545]	test-error:0.07500
# [546]	test-error:0.07500
# [547]	test-error:0.07500
# [548]	test-error:0.07500
# [549]	test-error:0.07500
# [550]	test-error:0.07500
# [551]	test-error:0.07500
# [552]	test-error:0.07500
# [553]	test-error:0.07500
# [554]	test-error:0.07500
# [555]	test-error:0.07500
# [556]	test-error:0.07500
# [557]	test-error:0.07500
# [558]	test-error:0.07500
# [559]	test-error:0.07500
# [560]	test-error:0.07500
# [561]	test-error:0.07500
# [562]	test-error:0.07500
# [563]	test-error:0.07500
# [564]	test-error:0.07500
# [565]	test-error:0.07500
# [566]	test-error:0.07500
# [567]	test-error:0.07500
# [568]	test-error:0.07500
# [569]	test-error:0.07500
# [570]	test-error:0.07500
# [571]	test-error:0.07500
# [572]	test-error:0.07500
# [573]	test-error:0.07500
# [574]	test-error:0.07500
# [575]	test-error:0.07500
# [576]	test-error:0.07500
# [577]	test-error:0.07500
# [578]	test-error:0.07500
# [579]	test-error:0.07500
# [580]	test-error:0.07500
# [581]	test-error:0.07500
# [582]	test-error:0.07500
# [583]	test-error:0.07500
# [584]	test-error:0.07500
# [585]	test-error:0.07500
# [586]	test-error:0.07500
# [587]	test-error:0.07500
# [588]	test-error:0.07500
# [589]	test-error:0.07500
# [590]	test-error:0.07500
# [591]	test-error:0.07500
# [592]	test-error:0.07500
# [593]	test-error:0.07500
# [594]	test-error:0.07500
# [595]	test-error:0.07500
# [596]	test-error:0.07500
# [597]	test-error:0.07500
# [598]	test-error:0.07500
# [599]	test-error:0.07500
# [600]	test-error:0.07500
# [601]	test-error:0.07500
# [602]	test-error:0.07500
# [603]	test-error:0.07500
# [604]	test-error:0.07500
# [605]	test-error:0.07500
# [606]	test-error:0.07500
# [607]	test-error:0.07500
# [608]	test-error:0.07500
# [609]	test-error:0.07500
# [610]	test-error:0.07500
# [611]	test-error:0.07500
# [612]	test-error:0.07500
# [613]	test-error:0.07500
# [614]	test-error:0.07500
# [615]	test-error:0.07500
# [616]	test-error:0.07500
# [617]	test-error:0.07500
# [618]	test-error:0.07500
# [619]	test-error:0.07500
# [620]	test-error:0.07500
# [621]	test-error:0.07500
# [622]	test-error:0.07500
# [623]	test-error:0.07500
# [624]	test-error:0.07500
# [625]	test-error:0.07500
# [626]	test-error:0.07500
# [627]	test-error:0.07500
# [628]	test-error:0.07500
# [629]	test-error:0.07500
# [630]	test-error:0.07500
# [631]	test-error:0.07500
# [632]	test-error:0.07500
# [633]	test-error:0.07500
# [634]	test-error:0.07500
# [635]	test-error:0.07500
# [636]	test-error:0.07500
# [637]	test-error:0.07500
# [638]	test-error:0.07500
# [639]	test-error:0.07500
# [640]	test-error:0.07500
# [641]	test-error:0.07500
# [642]	test-error:0.07500
# [643]	test-error:0.07500
# [644]	test-error:0.07500
# [645]	test-error:0.07500
# [646]	test-error:0.07500
# [647]	test-error:0.07500
# [648]	test-error:0.07500
# [649]	test-error:0.07500
# [650]	test-error:0.07500
# [651]	test-error:0.07500
# [652]	test-error:0.07500
# [653]	test-error:0.07500
# [654]	test-error:0.07500
# [655]	test-error:0.07500
# [656]	test-error:0.07500
# [657]	test-error:0.07500
# [658]	test-error:0.07500
# [659]	test-error:0.07500
# [660]	test-error:0.07500
# [661]	test-error:0.07500
# [662]	test-error:0.07500
# [663]	test-error:0.07500
# [664]	test-error:0.07500
# [665]	test-error:0.07500
# [666]	test-error:0.07500
# [667]	test-error:0.07500
# [668]	test-error:0.07500
# [669]	test-error:0.07500
# [670]	test-error:0.07500
# [671]	test-error:0.07500
# [672]	test-error:0.07500
# [673]	test-error:0.07500
# [674]	test-error:0.07500
# [675]	test-error:0.07500
# [676]	test-error:0.07500
# [677]	test-error:0.07500
# [678]	test-error:0.07500
# [679]	test-error:0.07500
# [680]	test-error:0.07500
# [681]	test-error:0.07500
# [682]	test-error:0.07500
# [683]	test-error:0.07500
# [684]	test-error:0.07500
# [685]	test-error:0.07500
# [686]	test-error:0.07500
# [687]	test-error:0.07500
# [688]	test-error:0.07500
# [689]	test-error:0.07500
# [690]	test-error:0.07500
# [691]	test-error:0.07500
# [692]	test-error:0.07500
# [693]	test-error:0.07500
# [694]	test-error:0.07500
# [695]	test-error:0.07500
# [696]	test-error:0.07500
# [697]	test-error:0.07500
# [698]	test-error:0.07500
# [699]	test-error:0.07500
# [700]	test-error:0.07500
# [701]	test-error:0.07500
# [702]	test-error:0.07500
# [703]	test-error:0.07500
# [704]	test-error:0.07500
# [705]	test-error:0.07500
# [706]	test-error:0.07500
# [707]	test-error:0.07500
# [708]	test-error:0.07500
# [709]	test-error:0.07500
# [710]	test-error:0.07500
# [711]	test-error:0.07500
# [712]	test-error:0.07500
# [713]	test-error:0.07500
# [714]	test-error:0.07500
# [715]	test-error:0.07500
# [716]	test-error:0.07500
# [717]	test-error:0.07500
# [718]	test-error:0.07500
# [719]	test-error:0.07500
# [720]	test-error:0.07500
# [721]	test-error:0.07500
# [722]	test-error:0.07500
# [723]	test-error:0.07500
# [724]	test-error:0.07500
# [725]	test-error:0.07500
# [726]	test-error:0.07500
# [727]	test-error:0.07500
# [728]	test-error:0.07500
# [729]	test-error:0.07500
# [730]	test-error:0.07500
# [731]	test-error:0.07500
# [732]	test-error:0.07500
# [733]	test-error:0.07500
# [734]	test-error:0.07500
# [735]	test-error:0.07500
# [736]	test-error:0.07500
# [737]	test-error:0.07500
# [738]	test-error:0.07500
# [739]	test-error:0.07500
# [740]	test-error:0.07500
# [741]	test-error:0.07500
# [742]	test-error:0.07500
# [743]	test-error:0.07500
# [744]	test-error:0.07500
# [745]	test-error:0.07500
# [746]	test-error:0.07500
# [747]	test-error:0.07500
# [748]	test-error:0.07500
# [749]	test-error:0.07500
# [750]	test-error:0.07500
# [751]	test-error:0.07500
# [752]	test-error:0.07500
# [753]	test-error:0.07500
# [754]	test-error:0.07500
# [755]	test-error:0.07500
# [756]	test-error:0.07500
# [757]	test-error:0.07500
# [758]	test-error:0.07500
# [759]	test-error:0.07500
# [760]	test-error:0.07500
# [761]	test-error:0.07500
# [762]	test-error:0.07500
# [763]	test-error:0.07500
# [764]	test-error:0.07500
# [765]	test-error:0.07500
# [766]	test-error:0.07500
# [767]	test-error:0.07500
# [768]	test-error:0.07500
# [769]	test-error:0.07500
# [770]	test-error:0.07500
# [771]	test-error:0.07500
# [772]	test-error:0.07500
# [773]	test-error:0.07500
# [774]	test-error:0.07500
# [775]	test-error:0.07500
# [776]	test-error:0.07500
# [777]	test-error:0.07500
# [778]	test-error:0.07500
# [779]	test-error:0.07500
# [780]	test-error:0.07500
# [781]	test-error:0.07500
# [782]	test-error:0.07500
# [783]	test-error:0.07500
# [784]	test-error:0.07500
# [785]	test-error:0.07500
# [786]	test-error:0.07500
# [787]	test-error:0.07500
# [788]	test-error:0.07500
# [789]	test-error:0.07500
# [790]	test-error:0.07500
# [791]	test-error:0.07500
# [792]	test-error:0.07500
# [793]	test-error:0.07500
# [794]	test-error:0.07500
# [795]	test-error:0.07500
# [796]	test-error:0.07500
# [797]	test-error:0.07500
# [798]	test-error:0.07500
# [799]	test-error:0.07500
# [800]	test-error:0.07500
# [801]	test-error:0.07500
# [802]	test-error:0.07500
# [803]	test-error:0.07500
# [804]	test-error:0.07500
# [805]	test-error:0.07500
# [806]	test-error:0.07500
# [807]	test-error:0.07500
# [808]	test-error:0.07500
# [809]	test-error:0.07500
# [810]	test-error:0.07500
# [811]	test-error:0.07500
# [812]	test-error:0.07500
# [813]	test-error:0.07500
# [814]	test-error:0.07500
# [815]	test-error:0.07500
# [816]	test-error:0.07500
# [817]	test-error:0.07500
# [818]	test-error:0.07500
# [819]	test-error:0.07500
# [820]	test-error:0.07500
# [821]	test-error:0.07500
# [822]	test-error:0.07500
# [823]	test-error:0.07500
# [824]	test-error:0.07500
# [825]	test-error:0.07500
# [826]	test-error:0.07500
# [827]	test-error:0.07500
# [828]	test-error:0.07500
# [829]	test-error:0.07500
# [830]	test-error:0.07500
# [831]	test-error:0.07500
# [832]	test-error:0.07500
# [833]	test-error:0.07500
# [834]	test-error:0.07500
# [835]	test-error:0.07500
# [836]	test-error:0.07500
# [837]	test-error:0.07500
# [838]	test-error:0.07500
# [839]	test-error:0.07500
# [840]	test-error:0.07500
# [841]	test-error:0.07500
# [842]	test-error:0.07500
# [843]	test-error:0.07500
# [844]	test-error:0.07500
# [845]	test-error:0.07500
# [846]	test-error:0.07500
# [847]	test-error:0.07500
# [848]	test-error:0.07500
# [849]	test-error:0.07500
# [850]	test-error:0.07500
# [851]	test-error:0.07500
# [852]	test-error:0.07500
# [853]	test-error:0.07500
# [854]	test-error:0.07500
# [855]	test-error:0.07500
# [856]	test-error:0.07500
# [857]	test-error:0.07500
# [858]	test-error:0.07500
# [859]	test-error:0.07500
# [860]	test-error:0.07500
# [861]	test-error:0.07500
# [862]	test-error:0.07500
# [863]	test-error:0.07500
# [864]	test-error:0.07500
# [865]	test-error:0.07500
# [866]	test-error:0.07500
# [867]	test-error:0.07500
# [868]	test-error:0.07500
# [869]	test-error:0.07500
# [870]	test-error:0.07500
# [871]	test-error:0.07500
# [872]	test-error:0.07500
# [873]	test-error:0.07500
# [874]	test-error:0.07500
# [875]	test-error:0.07500
# [876]	test-error:0.07500
# [877]	test-error:0.07500
# [878]	test-error:0.07500
# [879]	test-error:0.07500
# [880]	test-error:0.07500
# [881]	test-error:0.07500
# [882]	test-error:0.07500
# [883]	test-error:0.07500
# [884]	test-error:0.07500
# [885]	test-error:0.07500
# [886]	test-error:0.07500
# [887]	test-error:0.07500
# [888]	test-error:0.07500
# [889]	test-error:0.07500
# [890]	test-error:0.07500
# [891]	test-error:0.07500
# [892]	test-error:0.07500
# [893]	test-error:0.07500
# [894]	test-error:0.07500
# [895]	test-error:0.07500
# [896]	test-error:0.07500
# [897]	test-error:0.07500
# [898]	test-error:0.07500
# [899]	test-error:0.07500
# [900]	test-error:0.07500
# [901]	test-error:0.07500
# [902]	test-error:0.07500
# [903]	test-error:0.07500
# [904]	test-error:0.07500
# [905]	test-error:0.07500
# [906]	test-error:0.07500
# [907]	test-error:0.07500
# [908]	test-error:0.07500
# [909]	test-error:0.07500
# [910]	test-error:0.07500
# [911]	test-error:0.07500
# [912]	test-error:0.07500
# [913]	test-error:0.07500
# [914]	test-error:0.07500
# [915]	test-error:0.07500
# [916]	test-error:0.07500
# [917]	test-error:0.07500
# [918]	test-error:0.07500
# [919]	test-error:0.07500
# [920]	test-error:0.07500
# [921]	test-error:0.07500
# [922]	test-error:0.07500
# [923]	test-error:0.07500
# [924]	test-error:0.07500
# [925]	test-error:0.07500
# [926]	test-error:0.07500
# [927]	test-error:0.07500
# [928]	test-error:0.07500
# [929]	test-error:0.07500
# [930]	test-error:0.07500
# [931]	test-error:0.07500
# [932]	test-error:0.07500
# [933]	test-error:0.07500
# [934]	test-error:0.07500
# [935]	test-error:0.07500
# [936]	test-error:0.07500
# [937]	test-error:0.07500
# [938]	test-error:0.07500
# [939]	test-error:0.07500
# [940]	test-error:0.07500
# [941]	test-error:0.07500
# [942]	test-error:0.07500
# [943]	test-error:0.07500
# [944]	test-error:0.07500
# [945]	test-error:0.07500
# [946]	test-error:0.07500
# [947]	test-error:0.07500
# [948]	test-error:0.07500
# [949]	test-error:0.07500
# [950]	test-error:0.07500
# [951]	test-error:0.07500
# [952]	test-error:0.07500
# [953]	test-error:0.07500
# [954]	test-error:0.07500
# [955]	test-error:0.07500
# [956]	test-error:0.07500
# [957]	test-error:0.07500
# [958]	test-error:0.07500
# [959]	test-error:0.07500
# [960]	test-error:0.07500
# [961]	test-error:0.07500
# [962]	test-error:0.07500
# [963]	test-error:0.07500
# [964]	test-error:0.07500
# [965]	test-error:0.07500
# [966]	test-error:0.07500
# [967]	test-error:0.07500
# [968]	test-error:0.07500
# [969]	test-error:0.07500
# [970]	test-error:0.07500
# [971]	test-error:0.07500
# [972]	test-error:0.07500
# [973]	test-error:0.07500
# [974]	test-error:0.07500
# [975]	test-error:0.07500
# [976]	test-error:0.07500
# [977]	test-error:0.07500
# [978]	test-error:0.07500
# [979]	test-error:0.07500
# [980]	test-error:0.07500
# [981]	test-error:0.07500
# [982]	test-error:0.07500
# [983]	test-error:0.07500
# [984]	test-error:0.07500
# [985]	test-error:0.07500
# [986]	test-error:0.07500
# [987]	test-error:0.07500
# [988]	test-error:0.07500
# [989]	test-error:0.07500
# [990]	test-error:0.07500
# [991]	test-error:0.07500
# [992]	test-error:0.07500
# [993]	test-error:0.07500
# [994]	test-error:0.07500
# [995]	test-error:0.07500
# [996]	test-error:0.07500
# [997]	test-error:0.07500
# [998]	test-error:0.07500
# [999]	test-error:0.07500
# XGBoost
# Accuracy: 0.925
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91        19
#            1       0.88      1.00      0.93        21
#
#     accuracy                           0.93        40
#    macro avg       0.94      0.92      0.92        40
# weighted avg       0.93      0.93      0.92        40

# %%
# AdaBoost
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier()
ada.fit(X_train, y_train)
y_pred = ada.predict(X_test)

print('AdaBoost')
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# AdaBoost
# Accuracy: 0.925
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        19
#            1       0.91      0.95      0.93        21
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.92      0.92        40
# weighted avg       0.93      0.93      0.92        40
# c:\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
